# %% [markdown]
# # GHZ state fidelity data and analysis

# %%
import json
from GHZ_experiment import *

# %% [markdown]
# ### Load GHZ data from json files

# %%
with open('data/GHZ_N20.json', 'r') as f:
    GHZ_N20 = json.load(f)
    
with open('data/GHZ_N26.json', 'r') as f:
    GHZ_N26 = json.load(f)
    
with open('data/GHZ_N32.json', 'r') as f:
    GHZ_N32 = json.load(f)
    
with open('data/GHZ_N32_adap.json', 'r') as f:
    GHZ_N32_adap = json.load(f)

# %% [markdown]
# ## Make plots of populations and parities

# %%
exp_list = [GHZ_N20, GHZ_N26, GHZ_N32, GHZ_N32_adap]
plot_populations(exp_list)
plot_parities(exp_list)

# %% [markdown]
# <div align="center"> &copy; 2023 by Quantinuum. All Rights Reserved. </div>
